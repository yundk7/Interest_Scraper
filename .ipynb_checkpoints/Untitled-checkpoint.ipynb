# %%
pip freeze
# Out:
# absl-py==0.8.1
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# appnope==0.1.0
# asn1crypto==0.24.0
# astor==0.8.0
# astroid==2.2.5
# astropy==3.2.1
# atomicwrites==1.3.0
# attrs==19.1.0
# Babel==2.7.0
# backcall==0.1.0
# backports.functools-lru-cache==1.5
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.7.1
# bitarray==0.9.3
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.2.0
# boto==2.49.0
# boto3==1.9.241
# botocore==1.12.241
# Bottleneck==1.2.1
# branca==0.3.1
# CacheControl==0.12.5
# cachetools==3.1.1
# certifi==2019.6.16
# cffi==1.12.3
# chardet==3.0.4
# chart-studio==1.0.0
# Click==7.0
# cloudpickle==1.2.1
# clyent==1.2.2
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.7.10
# conda-build==3.18.8
# conda-package-handling==1.3.11
# conda-verify==3.4.2
# contextlib2==0.5.5
# cryptography==2.7
# cycler==0.10.0
# Cython==0.29.12
# cytoolz==0.10.0
# dash==1.2.0
# dash-core-components==1.1.2
# dash-html-components==1.0.1
# dash-renderer==1.0.1
# dash-table==4.2.0
# dask==2.1.0
# DateTime==4.3
# decorator==4.4.0
# defusedxml==0.6.0
# distributed==2.1.0
# docutils==0.14
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.1.0
# filelock==3.0.12
# Flask==1.1.1
# Flask-Compress==1.4.0
# Flask-SQLAlchemy==2.4.0
# folium==0.10.0
# future==0.17.1
# gast==0.2.2
# gevent==1.4.0
# glob2==0.7
# gmplot==1.2.0
# google-api-core==1.14.3
# google-auth==1.6.3
# google-cloud-core==1.0.3
# google-cloud-dataproc==0.5.0
# google-cloud-logging==1.14.0
# google-cloud-storage==1.20.0
# google-pasta==0.1.7
# google-resumable-media==0.4.1
# googleapis-common-protos==1.6.0
# greenlet==0.4.15
# grpcio==1.24.1
# gunicorn==19.9.0
# h5py==2.9.0
# heapdict==1.0.0
# html5lib==1.0.1
# idna==2.8
# imageio==2.5.0
# imagesize==1.1.0
# importlib-metadata==0.17
# ipykernel==5.1.1
# ipython==7.6.1
# ipython-genutils==0.2.0
# ipywidgets==7.5.0
# iso3166==1.0
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.13.3
# Jinja2==2.10.1
# jmespath==0.9.4
# joblib==0.13.2
# json5==0.8.4
# jsonschema==3.0.1
# jupyter==1.0.0
# jupyter-client==5.3.1
# jupyter-console==6.0.0
# jupyter-core==4.5.0
# jupyterlab==1.0.2
# jupyterlab-server==1.0.0
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keyring==18.0.0
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.1
# libarchive-c==2.8
# llvmlite==0.29.0
# locket==0.2.0
# lxml==4.3.4
# mapbox==0.18.0
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.0
# mccabe==0.6.1
# menuinst==1.4.16
# mistune==0.8.4
# mkl-fft==1.0.12
# mkl-random==1.0.2
# mkl-service==2.0.2
# mock==3.0.5
# more-itertools==7.0.0
# mpmath==1.1.0
# mrjob==0.6.11
# msgpack==0.6.1
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.5.0
# nbformat==4.4.0
# networkx==2.3
# nltk==3.4.4
# nose==1.3.7
# notebook==6.0.0
# numba==0.44.1
# numexpr==2.6.9
# numpy==1.16.4
# numpydoc==0.9.1
# olefile==0.46
# openpyxl==2.6.2
# opt-einsum==3.1.0
# packaging==19.0
# palettable==3.2.0
# pandas==0.24.2
# pandocfilters==1.4.2
# parso==0.5.0
# partd==1.0.0
# passlib==1.7.1
# path.py==12.0.1
# pathlib2==2.3.4
# patsy==0.5.1
# pep8==1.7.1
# pexpect==4.7.0
# pickleshare==0.7.5
# Pillow==6.1.0
# pkginfo==1.5.0.1
# plotly==4.1.0
# plotly-geo==1.0.0
# pluggy==0.12.0
# ply==3.11
# polyline==1.4.0
# prometheus-client==0.7.1
# prompt-toolkit==2.0.9
# protobuf==3.10.0
# psutil==5.6.3
# psycopg2==2.8.3
# ptyprocess==0.6.0
# py==1.8.0
# py4j==0.10.7
# pyasn1==0.4.7
# pyasn1-modules==0.2.7
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.3
# pyflakes==2.1.1
# Pygments==2.4.2
# pylint==2.3.1
# pyodbc==4.0.26
# pyOpenSSL==19.0.0
# pyparsing==2.4.0
# pyreadline==2.1
# pyrsistent==0.14.11
# pyshp==1.2.10
# PySocks==1.7.0
# pyspark==2.4.4
# pytest==5.0.1
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.3.0
# pytest-openfiles==0.3.2
# pytest-remotedata==0.3.1
# python-dateutil==2.8.0
# pytz==2019.1
# PyWavelets==1.0.3
# pywin32==223
# pywinpty==0.5.5
# PyYAML==5.1.1
# pyzmq==18.0.0
# QtAwesome==0.5.7
# qtconsole==4.5.1
# QtPy==1.8.0
# requests==2.22.0
# retrying==1.3.3
# rope==0.14.0
# rsa==4.0
# ruamel-yaml==0.15.46
# s3transfer==0.2.1
# scikit-image==0.15.0
# scikit-learn==0.21.2
# scipy==1.2.1
# seaborn==0.9.0
# selenium==3.141.0
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# snowballstemmer==1.9.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.8
# Sphinx==2.1.2
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.1.2
# splinter==0.11.0
# spyder==3.3.6
# spyder-kernels==0.5.1
# SQLAlchemy==1.3.5
# statsmodels==0.10.0
# sympy==1.4
# tables==3.5.2
# tblib==1.4.0
# tensorboard==2.0.0
# tensorflow==2.0.0
# tensorflow-estimator==2.0.0
# termcolor==1.1.0
# terminado==0.8.2
# testpath==0.4.2
# toolz==0.10.0
# tornado==6.0.3
# tqdm==4.32.1
# traitlets==4.3.2
# unicodecsv==0.14.1
# uritemplate==3.0.0
# urllib3==1.24.2
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.15.4
# widgetsnbextension==3.5.0
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wordcloud==1.5.0
# wrapt==1.11.2
# xlrd==1.2.0
# XlsxWriter==1.1.8
# xlwings==0.15.8
# xlwt==1.3.0
# zict==1.0.0
# zipp==0.5.1
# zope.interface==4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. import Flask
from flask import Flask, request, render_template, session, redirect, jsonify
import pandas as pd
from splinter import Browser
import requests
from bs4 import BeautifulSoup
import re
import operator as op
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
from IPython.display import Image
from IPython.core.display import HTML
from time import sleep

# %%
instaid = "dariapajak"
url = "https://www.instagram.com/" + instaid
browser = Browser('chrome')
browser.visit(url)
sleep(1)
bs = BeautifulSoup(browser.html, 'html.parser')

#finds all the images in website and puts url in df
images = bs.find_all('img', {'src':re.compile('.jpg')})
image_urls = []
for image in images: 
    image_urls.append(str(image['src']))
image_df = pd.DataFrame({"image":image_urls})

# %%
# import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

from PIL import Image
import requests
from io import BytesIO


model = Xception(
    include_top=True,
    weights='imagenet')

# %%
cnns = []
model = Xception(include_top=True,weights='imagenet')
for i in image_urls:
    url = i
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = img.resize((299, 299), Image.NEAREST)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    cnns.append(decode_predictions(predictions, top=1)[0][0][1])
image_df["CNN"] = cnns

# %%
image_df
# Out:
#                                                 image                      CNN
# 0   https://scontent-ort2-2.cdninstagram.com/vp/18...               volleyball
# 1   https://scontent-ort2-2.cdninstagram.com/vp/82...             balance_beam
# 2   https://scontent-ort2-2.cdninstagram.com/vp/e4...                 envelope
# 3   https://scontent-ort2-2.cdninstagram.com/vp/4b...                   screen
# 4   https://scontent-ort2-2.cdninstagram.com/vp/02...              trench_coat
# 5   https://scontent-ort2-2.cdninstagram.com/vp/3b...              oxygen_mask
# 6   https://scontent-ort2-2.cdninstagram.com/vp/b8...                 envelope
# 7   https://scontent-ort2-2.cdninstagram.com/vp/23...  black-and-tan_coonhound
# 8   https://scontent-ort2-2.cdninstagram.com/vp/e4...                corkscrew
# 9   https://scontent-ort2-2.cdninstagram.com/vp/1f...               neck_brace
# 10  https://scontent-ort2-2.cdninstagram.com/vp/eb...                seat_belt
# 11  https://scontent-ort2-2.cdninstagram.com/vp/38...             bullet_train
# 12  https://scontent-ort2-2.cdninstagram.com/vp/1f...                     oboe
# 13  https://scontent-ort2-2.cdninstagram.com/vp/06...             crash_helmet
# 14  https://scontent-ort2-2.cdninstagram.com/vp/68...             croquet_ball
# 15  https://scontent-ort2-2.cdninstagram.com/vp/da...               lumbermill
# 16  https://scontent-ort2-2.cdninstagram.com/vp/dc...                   jersey
# 17  https://scontent-ort2-2.cdninstagram.com/vp/c7...                     suit
# 18  https://scontent-ort2-2.cdninstagram.com/vp/7c...              feather_boa
# 19  https://scontent-ort2-2.cdninstagram.com/vp/ba...                miniskirt
# 20  https://scontent-ort2-2.cdninstagram.com/vp/6f...                  monitor
# 21  https://scontent-ort2-2.cdninstagram.com/vp/0d...               scoreboard
# 22  https://scontent-ort2-2.cdninstagram.com/vp/78...            digital_clock
# 23  https://scontent-ort2-2.cdninstagram.com/vp/57...                  barbell
# 24  https://scontent-ort2-2.cdninstagram.com/vp/c7...               volleyball
# 25  https://scontent-ort2-2.cdninstagram.com/vp/cb...                  bobsled
# 26  https://scontent-ort2-2.cdninstagram.com/vp/22...                miniskirt
# 27  https://scontent-ort2-2.cdninstagram.com/vp/dc...                bannister
# 28  https://scontent-ort2-2.cdninstagram.com/vp/fe...             bullet_train
# 29  https://scontent-ort2-2.cdninstagram.com/vp/df...             balance_beam
# 30  https://scontent-ort2-2.cdninstagram.com/vp/50...                    stage
# 31  https://scontent-ort2-2.cdninstagram.com/vp/51...               sweatshirt
# 32  https://scontent-ort2-2.cdninstagram.com/vp/19...                 dumbbell

# %%
image_urls[0]
# Out:
# 'https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com'

# %%
url
# Out:
# 'https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com'

# %%
# url = "https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com"
url = image_urls[2]
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img2 = img.resize((299, 299),Image.NEAREST)

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x2C1275C7E80>

# %%
x = image.img_to_array(img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b5298e393905> in <module>
# ----> 1 x = image.img_to_array(img2)
#
# TypeError: 'NoneType' object is not callable

# %%
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
predictions = model.predict(x)
# cnns.append(decode_predictions(predictions, top=1)[0][0][1])
decode_predictions(predictions, top=1)[0][0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-77d8061b3d67> in <module>
# ----> 1 x = np.expand_dims(x, axis=0)
#       2 x = preprocess_input(x)
#       3 predictions = model.predict(x)
#       4 # cnns.append(decode_predictions(predictions, top=1)[0][0][1])
#       5 decode_predictions(predictions, top=1)[0][0][1]
#
# NameError: name 'x' is not defined

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x1719F2BBA58>
