# %%
# 1. import Flask
from flask import Flask, request, render_template, session, redirect, jsonify
import pandas as pd
from splinter import Browser
import requests
from bs4 import BeautifulSoup
import re
import operator as op
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
from IPython.display import Image
from IPython.core.display import HTML
from time import sleep

# %%
# import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
instaid = "jenniferaniston"
url = "https://www.instagram.com/" + instaid
browser = Browser('chrome')
browser.visit(url)
sleep(1)
bs = BeautifulSoup(browser.html, 'html.parser')

#finds all the images in website and puts url in df
images = bs.find_all('img', {'src':re.compile('.jpg')})
image_urls = []
for image in images: 
    image_urls.append(str(image['src']))
image_df = pd.DataFrame({"image":image_urls})

# %%
image_urls
# Out:
# ['https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com',
#  'https://scontent-ort2-2.cdninstagram.com/vp/9be5c56cca9fdc2afb0d0baa66faad91/5E4B202A/t51.2885-15/sh0.08/e35/c0.167.1395.1395a/s640x640/74377320_558729924895478_2323983456164757356_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=1',
#  'https://scontent-ort2-2.cdninstagram.com/vp/8fb68a0adf290ec9b1b01220ec372dd0/5DBCAB43/t51.2885-15/sh0.08/e35/s640x640/73034851_807595573013941_3231977547037167666_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=1',
#  'https://scontent-ort2-2.cdninstagram.com/vp/8c584d090d1dcafa9808657bd26066d0/5E520B86/t51.2885-15/sh0.08/e35/c0.158.1366.1366a/s640x640/73061389_473129243549695_6141546963828521423_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=1',
#  'https://scontent-ort2-2.cdninstagram.com/vp/85e86f33832375e9a01d2f567ba495cc/5E408502/t51.2885-15/sh0.08/e35/c0.49.1073.1073a/s640x640/72480381_793611767736391_6518567562907738477_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=1',
#  'https://scontent-ort2-2.cdninstagram.com/vp/63ca7d7aebcadcd04f7d8791439a9499/5DBC887D/t51.2885-15/sh0.08/e35/c0.90.720.720a/s640x640/70961222_775278426241149_4879234955127448101_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=1',
#  'https://scontent-ort2-2.cdninstagram.com/vp/5173f8199d05a7c4656d019c2310db75/5E58FAD1/t51.2885-15/sh0.08/e35/c0.82.1389.1389a/s640x640/70777698_601477490388334_6333729180293366273_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com&_nc_cat=110']

# %%
cnns = []
model = Xception(include_top=True,weights='imagenet')
for i in image_urls:
    url = i
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = img.resize((299, 299), Image.NEAREST)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    cnns.append(decode_predictions(predictions, top=1)[0][0][1])
image_df["CNN"] = cnns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c8b75736b62f> in <module>
#       6     img = Image.open(BytesIO(response.content))
#       7     img = img.resize((299, 299), Image.NEAREST)
# ----> 8     x = image.img_to_array(img)
#       9     x = np.expand_dims(x, axis=0)
#      10     x = preprocess_input(x)
#
# TypeError: 'NoneType' object is not callable

# %%
image_urls[0]
# Out:
# 'https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com'

# %%
url
# Out:
# 'https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com'

# %%
# url = "https://scontent-ort2-2.cdninstagram.com/vp/6e125e29c666c1e9f181d4c7a7df7a86/5E45C63A/t51.2885-19/s320x320/71594249_1125833014288751_8012044229767331840_n.jpg?_nc_ht=scontent-ort2-2.cdninstagram.com"
url = image_urls[3]
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img2 = img.resize((299, 299),Image.ANTIALIAS)

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x2C1275C7630>

# %%
x = image.img_to_array(img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b5298e393905> in <module>
# ----> 1 x = image.img_to_array(img2)
#
# TypeError: 'NoneType' object is not callable

# %%
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
predictions = model.predict(x)
# cnns.append(decode_predictions(predictions, top=1)[0][0][1])
decode_predictions(predictions, top=1)[0][0][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-83694468acff> in <module>
#       4 img = Image.open(BytesIO(response.content))
#       5 img = img.resize((299, 299), Image.NEAREST)
# ----> 6 x = image.img_to_array(img)
#       7 x = np.expand_dims(x, axis=0)
#       8 x = preprocess_input(x)
#
# TypeError: 'NoneType' object is not callable

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x1719F2BBA58>
